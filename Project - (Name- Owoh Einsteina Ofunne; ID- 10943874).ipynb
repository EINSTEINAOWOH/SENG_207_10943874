# %% [markdown]
# # <span style="font-family:Times New Roman"> SENG 207 - Programming for Engineers
#
# ## <u><span style="font-family:Times New Roman"> Project 1 </span></u>
# #### <span style="font-family:Times New Roman; font-size:1.25em"> Name: Owoh Einsteina Ofunne </span>
# #### <span style="font-family:Times New Roman; font-size:1.25em"> ID: 10943874 </span>
# #### <span style="font-family:Times New Roman; font-size:1.25em"> Department: Computer Engineering </span>

# %% [markdown]
# ---

# %%
# Impoting pandas library for data analysis
import pandas as pd

# %%
#Importing several libraries for graph construction
import matplotlib as mt
import numpy as np
import seaborn as sb

# %%
dt = pd.read_csv('data.csv')

# %%
dt
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## <span style="font-family:Times New Roman"> Pre-processing the Data</span>
# ---

# %% [markdown]
#
# <span style="font-family:Times New Roman; font-size:1.25em">In order to remove the null values, I have decided to drop the rows that have null values instead of filling it with values that may not be accurate . </span>

# %%
z = dt.dropna()

# %%
z
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# <span style="font-family:Times New Roman; font-size:1.25em">
# The next step in cleaning the data is to remove any duplicates present.
# </span>

# %%
y = z.drop_duplicates()
y
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## <span style="font-family:Times New Roman">Statistical Inferences</span>
# ---
#
# <span style="font-family:Times New Roman; font-size:1.25em">Now that the document is cleaned, I can perform data analysis on it. The first I am going to do is show the statistical inferences of the entire dataset.</span>

# %%
x = y.describe()
x
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %% [markdown]
# <span style="font-family:Times New Roman; font-size:1.25em">I will remove the ID column for the charts that will be included later in the document because it just serves as an index and influences the scale of other bars.</span>

# %%
x = x.iloc[: , 1:]
x
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1591.000000       1591.000000  1591.000000     1591.000000
# mean        8.320616          0.527681     0.271477        2.540761
# std         1.740134          0.179045     0.194807        1.413076
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1591.000000          1591.000000           1591.000000  1591.000000
# mean      0.087500            15.861722             46.498429     0.996747
# std       0.047175            10.429385             32.998659     0.001889
# ...

# %% [markdown]
# <br>
# <br>
# <span style="font-family:Times New Roman; font-size:1.25em">Additionally, I can show the statistical inferences for each column.</span>
# <br>
# <br>

# %%
y['fixed acidity'].describe()
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
y['volatile acidity'].describe()
# Out:
# count    1591.000000
# mean        0.527681
# std         0.179045
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
y['citric acid'].describe()
# Out:
# count    1591.000000
# mean        0.271477
# std         0.194807
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
y['residual sugar'].describe()
# Out:
# count    1591.000000
# mean        2.540761
# std         1.413076
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
y['chlorides'].describe()
# Out:
# count    1591.000000
# mean        0.087500
# std         0.047175
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
y['free sulfur dioxide'].describe()
# Out:
# count    1591.000000
# mean       15.861722
# std        10.429385
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
y['total sulfur dioxide'].describe()
# Out:
# count    1591.000000
# mean       46.498429
# std        32.998659
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
y['density'].describe()
# Out:
# count    1591.000000
# mean        0.996747
# std         0.001889
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997845
# max         1.003690
# Name: density, dtype: float64

# %%
y['pH'].describe()
# Out:
# count    1591.000000
# mean        3.311358
# std         0.154548
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
y['sulphates'].describe()
# Out:
# count    1591.000000
# mean        0.658611
# std         0.169786
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
y['alcohol'].describe()
# Out:
# count    1591.000000
# mean       10.426053
# std         1.066706
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
y['quality'].describe()
# Out:
# count    1591.000000
# mean        5.637964
# std         0.807772
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## <span style="font-family:Times New Roman">Hidden Inferences</span>
# ---

# %% [markdown]
# <span style="font-family:Times New Roman; font-size:1.25em">Furthermore, I can show the hidden inferences of the data set using histograms and heatmaps.</span>

# %%
sb.set()
y.hist(figsize=(10,10), color='pink')
mt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[117], line 3
#       1 sb.set()
#       2 y.hist(figsize=(10,10), color='pink')
# ----> 3 mt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %% [markdown]
# ### <span style="font-family:Times New Roman">Data Correlation:
# ---

# %%
y.corr()
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.268371         -0.006833    -0.156712
# fixed acidity        -0.268371       1.000000         -0.256737     0.672306
# volatile acidity     -0.006833      -0.256737          1.000000    -0.551511
# citric acid          -0.156712       0.672306         -0.551511     1.000000
# residual sugar       -0.031780       0.114839          0.001336     0.143731
# chlorides            -0.119930       0.093857          0.061202     0.204294
# free sulfur dioxide   0.085616      -0.150261         -0.014598    -0.057619
# total sulfur dioxide -0.115795      -0.110992          0.074132     0.038593
# density              -0.368878       0.666876          0.022504     0.364181
# pH                    0.133390      -0.683788          0.234251    -0.543230
# sulphates            -0.127397       0.184937         -0.261872     0.313530
# ...
